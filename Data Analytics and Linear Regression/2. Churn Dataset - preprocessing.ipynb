# %% [markdown]
# # Continue Data Analysis

# %%
import pandas as pd

# %%
# Read from the CSV file
df = pd.read_csv("customer_churn_v1.csv")

# %%
df.info()

# %%
df.head()

# %%
# Read from the pickle file v1
df = pd.read_pickle("customer_churn_v1.pkl")

# %%
df.head()
# Out:
#    customer_id  vintage  age gender  dependents     occupation    city  \
# 0            1     2401   66   Male           0  self_employed   187.0
# 1            2     2648   35   Male           0  self_employed     NaN
# 2            4     2494   31   Male           0       salaried   146.0
# 3            5     2629   90    NaN        <NA>  self_employed  1020.0
# 4            6     1879   42   Male           2  self_employed  1494.0
#
#   customer_nw_category branch_code  current_balance  ...  \
# 0                    2         755          1458.71  ...
# 1                    2        3214          5390.37  ...
# 2                    2          41          3913.16  ...
# 3                    2         582          2291.91  ...
# 4                    3         388           927.72  ...
#
#    previous_month_credit  current_month_debit  previous_month_debit  \
# 0                   0.20                 0.20                  0.20
# 1                   0.56              5486.27                100.56
# 2                   0.61              6046.73                259.23
# 3                   0.47                 0.47               2143.33
# 4                 714.61               588.62               1538.06
#
#    current_month_balance  previous_month_balance  churn  doy_ls_tran  \
# 0                1458.71                 1458.71    0.0        141.0
# 1                6496.78                 8787.61    0.0        305.0
# 2                5006.28                 5070.14    0.0          NaN
# 3                2291.91                 1669.79    1.0        218.0
# 4                1157.15                 1677.16    1.0        307.0
#
#    woy_ls_tran  moy_ls_tran dow_ls_tran
# 0           21          5.0         1.0
# 1           44         11.0         4.0
# 2         <NA>          NaN         NaN
# 3           32          8.0         1.0
# 4           44         11.0         6.0
#
# [5 rows x 24 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15930 entries, 0 to 15929
# Data columns (total 24 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   customer_id                     15930 non-null  int64
#  1   vintage                         15930 non-null  int64
#  2   age                             15930 non-null  int64
#  3   gender                          15642 non-null  category
#  4   dependents                      14582 non-null  Int64
#  5   occupation                      15883 non-null  category
#  6   city                            15470 non-null  category
#  7   customer_nw_category            15930 non-null  category
#  8   branch_code                     15930 non-null  category
#  9   current_balance                 15930 non-null  float64
#  10  previous_month_end_balance      15930 non-null  float64
#  11  average_monthly_balance_prevQ   15930 non-null  float64
#  12  average_monthly_balance_prevQ2  15930 non-null  float64
#  13  current_month_credit            15930 non-null  float64
#  14  previous_month_credit           15930 non-null  float64
#  15  current_month_debit             15930 non-null  float64
#  16  previous_month_debit            15929 non-null  float64
#  17  current_month_balance           15929 non-null  float64
#  18  previous_month_balance          15929 non-null  float64
#  19  churn                           15929 non-null  category
#  20  doy_ls_tran                     14118 non-null  float64
#  21  woy_ls_tran                     14118 non-null  UInt32
#  22  moy_ls_tran                     14118 non-null  float64
#  23  dow_ls_tran                     14118 non-null  float64
# dtypes: Int64(1), UInt32(1), category(6), float64(13), int64(3)
# memory usage: 2.3 MB

# %%
pd.set_option('display.precision', 2)

# %%
df.describe().T # quick statistical summary of the numeric variables
# Out:
#                                   count     mean       std      min      25%  \
# customer_id                     15930.0  8498.09   4910.08      1.0  4245.25
# vintage                         15930.0  2392.44    272.49    438.0   2260.0
# age                             15930.0    48.17     17.87      1.0     35.0
# dependents                      14582.0     0.36      1.09      0.0      0.0
# current_balance                 15930.0  7271.42  50511.91 -5503.96  1776.39
# previous_month_end_balance      15930.0  7386.99  49442.42 -2998.64  1908.64
# average_monthly_balance_prevQ   15930.0   7433.5   48935.4  1428.69  2168.16
# average_monthly_balance_prevQ2  15930.0  7183.79  55285.74 -16506.1  1822.05
# current_month_credit            15930.0   3279.2  31247.26     0.01     0.31
# previous_month_credit           15930.0  3419.49  35412.68     0.01     0.33
# current_month_debit             15930.0   3498.2  28257.28     0.01     0.41
# previous_month_debit            15929.0  3466.23  27720.81     0.01     0.41
# current_month_balance           15929.0  7362.58  49338.07 -3374.18  1988.66
# previous_month_balance          15929.0  7438.76  49736.15 -3060.13  2077.04
# doy_ls_tran                     14118.0   295.71     85.57      1.0    270.0
# woy_ls_tran                     14118.0    39.04     15.97      1.0     33.0
# moy_ls_tran                     14118.0    10.16      2.76      1.0      9.0
# dow_ls_tran                     14118.0     3.04      1.71      0.0      1.0
#
#                                     50%       75%         max
# customer_id                      8485.5  12752.75     16997.0
# vintage                          2454.0    2593.0      2776.0
# age                                46.0      60.0        90.0
# dependents                          0.0       0.0        52.0
# current_balance                 3276.64   6624.46  5905904.03
# previous_month_end_balance      3381.18   6686.01  5740438.63
# average_monthly_balance_prevQ   3520.03   6676.24  5700289.57
# average_monthly_balance_prevQ2  3373.78   6532.69   5010170.1
# current_month_credit               0.61    707.58  1764285.97
# previous_month_credit              0.64    771.84  2361808.29
# current_month_debit                94.4   1393.23  1764285.97
# previous_month_debit             112.48   1357.73  1414168.06
# current_month_balance           3445.41   6658.49  5778184.77
# previous_month_balance          3450.51   6679.81   5720144.5
# doy_ls_tran                       335.0     354.0       365.0
# woy_ls_tran                        47.0      50.0        52.0
# moy_ls_tran                        12.0      12.0        12.0
# dow_ls_tran                         3.0       5.0         6.0

# %%
# statistical summary for the categorical columns
df.describe(include='category')
# Out:
#        gender     occupation     city  customer_nw_category  branch_code  \
# count   15642          15883  15470.0                 15930        15930
# unique      2              5   1287.0                     3         2806
# top      Male  self_employed   1020.0                     2            6
# freq     9308           9814   1949.0                  8164           75
#
#           churn
# count   15929.0
# unique      2.0
# top         0.0
# freq    12942.0

# %%
100*288/9308  # 3% missing vlaues
# Out:
# 3.0941125913192953

# %%
100*47/9814  # less than 0.5% missing vlaues
# Out:
# 0.4789076829019768

# %%
100*460/1949  # 24 % of the top most value
# Out:
# 23.601847101077475

# %%
9308/len(df)  # top most vlaue in gender is already 58% of the dataset
# Out:
# 0.5843063402385437

# %%
9814/len(df)  # top most vlaue in occupation is already 61% of the dataset
# Out:
# 0.6160703075957313

# %%
100*1949/len(df)  # top most vlaue in city is ONLY 12% of the dataset
# Out:
# 12.234777150031388

# %% [markdown]
# # Missing values

# %%
# list of all the columns having missing vlaues & the number f missing values
df.isna().sum()
# Out:
# customer_id                          0
# vintage                              0
# age                                  0
# gender                             288
# dependents                        1348
# occupation                          47
# city                               460
# customer_nw_category                 0
# branch_code                          0
# current_balance                      0
# previous_month_end_balance           0
# average_monthly_balance_prevQ        0
# average_monthly_balance_prevQ2       0
# current_month_credit                 0
# previous_month_credit                0
# current_month_debit                  0
# previous_month_debit                 1
# current_month_balance                1
# previous_month_balance               1
# churn                                1
# doy_ls_tran                       1812
# woy_ls_tran                       1812
# moy_ls_tran                       1812
# dow_ls_tran                       1812
# dtype: int64

# %%
# get the number of missing values for gender column only
df['gender'].isnull().sum()
# Out:
# 288

# %%
df['gender']
# Out:
# 0          Male
# 1          Male
# 2          Male
# 3           NaN
# 4          Male
#           ...
# 15925    Female
# 15926      Male
# 15927    Female
# 15928    Female
# 15929      Male
# Name: gender, Length: 15930, dtype: category
# Categories (2, object): ['Female', 'Male']

# %%
df['gender'].mode()[0]
# Out:
# 'Male'

# %%
# TO DO: Fill the missing values of gender column with the mode value
df['gender'].fillna(value = df['gender'].mode()[0], inplace=True)

# %%
df['gender'].isna().sum()   # there no more missing vlues
# Out:
# 0

# %%
df['occupation'].mode()[0]
# Out:
# 'self_employed'

# %%
# TO DO: Fill the missing values of occupation column with the mode value
df['occupation'].fillna(value = df['occupation'].mode()[0], inplace=True)

# %%
df['occupation'].isna().sum()
# Out:
# 0

# %%
df.city.nunique()
# Out:
# 1287

# %% [markdown]
# ## Missing values in the depedents Col

# %%
df['dependents'].mean()
# Out:
# 0.3567411877657386

# %%
df['dependents'].value_counts(normalize=True)
# Out:
# 0     0.82
# 2     0.08
# 1     0.05
# 3     0.03
# 4     0.01
# 5      0.0
# 6      0.0
# 7      0.0
# 9      0.0
# 52     0.0
# 36     0.0
# 50     0.0
# 8      0.0
# 25     0.0
# Name: dependents, dtype: Float64

# %%
df['dependents'].value_counts(normalize=True, dropna=False)
# Out:
# 0       0.75
# <NA>    0.08
# 2       0.08
# 1       0.05
# 3       0.03
# 4       0.01
# 5        0.0
# 6        0.0
# 7        0.0
# 9        0.0
# 52       0.0
# 36       0.0
# 50       0.0
# 8        0.0
# 25       0.0
# Name: dependents, dtype: Float64

# %%
df['dependents'].isna().sum()
# Out:
# 1348

# %%
df['dependents'].skew()
# Out:
# 18.331508782973817

# %%
df['dependents'].mean(), df['dependents'].median(), df['dependents'].mode()
# Out:
# (0.3567411877657386,
#  0.0,
#  0    0
#  Name: dependents, dtype: Int64)

# %%
gp = df.groupby(df['occupation'])
gp['dependents'].mean()
# Avg no. of depedents for each occupation type
# Out:
# occupation
# company          0.29
# retired          0.13
# salaried         0.42
# self_employed     0.4
# student          0.02
# Name: dependents, dtype: Float64

# %%
gp = df.groupby(df['churn'])
gp['dependents'].mean()
# Avg no. of depedents for each churn type
# Out:
# churn
# 0.0    0.34
# 1.0    0.43
# Name: dependents, dtype: Float64

# %%
gp = df.groupby(df['gender'])
gp['dependents'].mean().round()
# Out:
# gender
# Female    0.0
# Male      1.0
# Name: dependents, dtype: Float64

# %%
# wherever the dependents is NAN & gender is male, replace it with 1
# wherever the dependents is NAN & gender is female, replace it with 0

# %%
# Implement the strategy no. 2
# wherever the dependents is NAN & gender is male, replace it with 1
# wherever the dependents is NAN & gender is female, replace it with 0

def impute_nan_dependents(cols):
    gender = cols[0]
    dep = cols[1]
    
    if pd.isnull(dep):
        if gender == "Male": 
            return 1  # replace the NaN with 1, when gender is Male
        elif gender == "Female":
            return 0  # replace the NaN with 0, when gender is Female
    else:
        return dep # return the same value of dependents if it is not null

# %%
df[['gender', 'dependents']].head()
# Out:
#   gender  dependents
# 0   Male           0
# 1   Male           0
# 2   Male           0
# 3   Male        <NA>
# 4   Male           2

# %%
df['dependents'] = df[['gender', 'dependents']].apply(impute_nan_dependents, axis=1)

# %%
df[['gender', 'dependents']].head()
# Out:
#   gender  dependents
# 0   Male           0
# 1   Male           0
# 2   Male           0
# 3   Male           1
# 4   Male           2

# %%
df.isna().sum()
# Out:
# customer_id                          0
# vintage                              0
# age                                  0
# gender                               0
# dependents                           0
# occupation                           0
# city                                 0
# customer_nw_category                 0
# branch_code                          0
# current_balance                      0
# previous_month_end_balance           0
# average_monthly_balance_prevQ        0
# average_monthly_balance_prevQ2       0
# current_month_credit                 0
# previous_month_credit                0
# current_month_debit                  0
# previous_month_debit                 1
# current_month_balance                1
# previous_month_balance               1
# churn                                1
# doy_ls_tran                       1812
# woy_ls_tran                       1812
# moy_ls_tran                       1812
# dow_ls_tran                       1812
# dtype: int64

# %%
df.tail()
# Out:
#        customer_id  vintage  age  gender  dependents     occupation  city  \
# 15925        16993     2500   64  Female           0  self_employed   409
# 15926        16994     2470   44    Male           0       salaried  1020
# 15927        16995     2537   34  Female           1  self_employed  2010
# 15928        16996     2287   56  Female           0  self_employed  2010
# 15929        16997     2656   70    Male           0  self_employed  1096
#
#       customer_nw_category branch_code  current_balance  ...  \
# 15925                    3         934           309.64  ...
# 15926                    2          15          1049.67  ...
# 15927                    2         284          1106.86  ...
# 15928                    2         670          2098.29  ...
# 15929                    2         134         18530.60  ...
#
#        previous_month_credit  current_month_debit  previous_month_debit  \
# 15925               46961.44              5148.76              41642.90
# 15926                 966.96              1428.63               5714.34
# 15927                1714.39              8618.20               1142.96
# 15928                   0.26               143.11                314.54
# 15929                 156.55                 0.19                   NaN
#
#        current_month_balance  previous_month_balance  churn  doy_ls_tran  \
# 15925                2733.69                 2340.96    1.0        332.0
# 15926                2100.30                 1846.93    1.0        335.0
# 15927                5726.47                  605.49    0.0        341.0
# 15928                2132.49                 2083.49    0.0        341.0
# 15929                    NaN                     NaN    NaN          NaN
#
#        woy_ls_tran  moy_ls_tran dow_ls_tran
# 15925           48         11.0         3.0
# 15926           48         12.0         6.0
# 15927           49         12.0         5.0
# 15928           49         12.0         5.0
# 15929         <NA>          NaN         NaN
#
# [5 rows x 24 columns]

# %%
# dropping the customer_id col
df.drop("customer_id", axis=1, inplace=True)

# %%
df.head()
# Out:
#    vintage  age gender  dependents     occupation    city  \
# 0     2401   66   Male           0  self_employed    2004
# 1     2648   35   Male           0  self_employed  100000
# 2     2494   31   Male           0       salaried     146
# 3     2629   90   Male           1  self_employed    1020
# 4     1879   42   Male           2  self_employed    1494
#
#   customer_nw_category branch_code  current_balance  \
# 0                    2         755          1458.71
# 1                    2        3214          5390.37
# 2                    2          41          3913.16
# 3                    2         582          2291.91
# 4                    3         388           927.72
#
#    previous_month_end_balance  ...  previous_month_credit  \
# 0                     1458.71  ...                   0.20
# 1                     8704.66  ...                   0.56
# 2                     5815.29  ...                   0.61
# 3                     2291.91  ...                   0.47
# 4                     1401.72  ...                 714.61
#
#    current_month_debit  previous_month_debit  current_month_balance  \
# 0                 0.20                  0.20                1458.71
# 1              5486.27                100.56                6496.78
# 2              6046.73                259.23                5006.28
# 3                 0.47               2143.33                2291.91
# 4               588.62               1538.06                1157.15
#
#    previous_month_balance  churn  doy_ls_tran  woy_ls_tran moy_ls_tran  \
# 0                 1458.71    0.0        141.0           21         5.0
# 1                 8787.61    0.0        305.0           44        11.0
# 2                 5070.14    0.0          NaN         <NA>         NaN
# 3                 1669.79    1.0        218.0           32         8.0
# 4                 1677.16    1.0        307.0           44        11.0
#
#    dow_ls_tran
# 0          1.0
# 1          4.0
# 2          NaN
# 3          1.0
# 4          6.0
#
# [5 rows x 23 columns]

# %%
df[df.churn.isnull()]  # fetch the row where Churn is missing
# Out:
#        vintage  age gender  dependents     occupation  city  \
# 15929     2656   70   Male           0  self_employed  1096
#
#       customer_nw_category branch_code  current_balance  \
# 15929                    2         134          18530.6
#
#        previous_month_end_balance  ...  previous_month_credit  \
# 15929                    18222.58  ...                 156.55
#
#        current_month_debit  previous_month_debit  current_month_balance  \
# 15929                 0.19                   NaN                    NaN
#
#        previous_month_balance  churn  doy_ls_tran  woy_ls_tran moy_ls_tran  \
# 15929                     NaN    NaN          NaN         <NA>         NaN
#
#        dow_ls_tran
# 15929          NaN
#
# [1 rows x 23 columns]

# %%
df[df.churn.isnull()].index[0]
# Out:
# 15929

# %%
# Drop those rows where churn is null
df.drop(df[df.churn.isnull()].index[0], axis=0, inplace=True)

# %%
df.tail()
# Out:
#        vintage  age  gender  dependents     occupation  city  \
# 15924     2175   40    Male           0       salaried  2010
# 15925     2500   64  Female           0  self_employed   409
# 15926     2470   44    Male           0       salaried  1020
# 15927     2537   34  Female           1  self_employed  2010
# 15928     2287   56  Female           0  self_employed  2010
#
#       customer_nw_category branch_code  current_balance  \
# 15924                    2         231          9996.84
# 15925                    3         934           309.64
# 15926                    2          15          1049.67
# 15927                    2         284          1106.86
# 15928                    2         670          2098.29
#
#        previous_month_end_balance  ...  previous_month_credit  \
# 15924                    10032.93  ...                9923.99
# 15925                     5458.35  ...               46961.44
# 15926                     2716.22  ...                 966.96
# 15927                      992.59  ...                1714.39
# 15928                     1879.26  ...                   0.26
#
#        current_month_debit  previous_month_debit  current_month_balance  \
# 15924                 0.10                  0.10               10009.28
# 15925              5148.76              41642.90                2733.69
# 15926              1428.63               5714.34                2100.30
# 15927              8618.20               1142.96                5726.47
# 15928               143.11                314.54                2132.49
#
#        previous_month_balance  churn  doy_ls_tran  woy_ls_tran moy_ls_tran  \
# 15924                 7483.44    0.0        314.0           45        11.0
# 15925                 2340.96    1.0        332.0           48        11.0
# 15926                 1846.93    1.0        335.0           48        12.0
# 15927                  605.49    0.0        341.0           49        12.0
# 15928                 2083.49    0.0        341.0           49        12.0
#
#        dow_ls_tran
# 15924          6.0
# 15925          3.0
# 15926          6.0
# 15927          5.0
# 15928          5.0
#
# [5 rows x 23 columns]

# %%
df.isna().sum()
# Out:
# vintage                              0
# age                                  0
# gender                               0
# dependents                           0
# occupation                           0
# city                                 0
# customer_nw_category                 0
# branch_code                          0
# current_balance                      0
# previous_month_end_balance           0
# average_monthly_balance_prevQ        0
# average_monthly_balance_prevQ2       0
# current_month_credit                 0
# previous_month_credit                0
# current_month_debit                  0
# previous_month_debit                 0
# current_month_balance                0
# previous_month_balance               0
# churn                                0
# doy_ls_tran                       1811
# woy_ls_tran                       1811
# moy_ls_tran                       1811
# dow_ls_tran                       1811
# dtype: int64

# %%
df.to_pickle("churn_prediction_v2.pkl")

# %%
df.drop(['gender', 'dependents'], axis=1, inplace=True)

# %%
df.head()
# Out:
#    vintage  age     occupation    city customer_nw_category branch_code  \
# 0     2401   66  self_employed    2004                    2         755
# 1     2648   35  self_employed  100000                    2        3214
# 2     2494   31       salaried     146                    2          41
# 3     2629   90  self_employed    1020                    2         582
# 4     1879   42  self_employed    1494                    3         388
#
#    current_balance  previous_month_end_balance  average_monthly_balance_prevQ  \
# 0          1458.71                     1458.71                        1458.71
# 1          5390.37                     8704.66                        7799.26
# 2          3913.16                     5815.29                        4910.17
# 3          2291.91                     2291.91                        2084.54
# 4           927.72                     1401.72                        1643.31
#
#    average_monthly_balance_prevQ2  ...  previous_month_credit  \
# 0                         1449.07  ...                   0.20
# 1                        12419.41  ...                   0.56
# 2                         2815.94  ...                   0.61
# 3                         1006.54  ...                   0.47
# 4                         1871.12  ...                 714.61
#
#    current_month_debit  previous_month_debit  current_month_balance  \
# 0                 0.20                  0.20                1458.71
# 1              5486.27                100.56                6496.78
# 2              6046.73                259.23                5006.28
# 3                 0.47               2143.33                2291.91
# 4               588.62               1538.06                1157.15
#
#    previous_month_balance  churn doy_ls_tran  woy_ls_tran  moy_ls_tran  \
# 0                 1458.71    0.0       141.0           21          5.0
# 1                 8787.61    0.0       305.0           44         11.0
# 2                 5070.14    0.0         NaN         <NA>          NaN
# 3                 1669.79    1.0       218.0           32          8.0
# 4                 1677.16    1.0       307.0           44         11.0
#
#    dow_ls_tran
# 0          1.0
# 1          4.0
# 2          NaN
# 3          1.0
# 4          6.0
#
# [5 rows x 21 columns]

# %%
df = pd.read_pickle("churn_prediction_v2.pkl")
df.head()
# Out:
#    vintage  age gender  dependents     occupation    city  \
# 0     2401   66   Male           0  self_employed    2004
# 1     2648   35   Male           0  self_employed  100000
# 2     2494   31   Male           0       salaried     146
# 3     2629   90   Male           1  self_employed    1020
# 4     1879   42   Male           2  self_employed    1494
#
#   customer_nw_category branch_code  current_balance  \
# 0                    2         755          1458.71
# 1                    2        3214          5390.37
# 2                    2          41          3913.16
# 3                    2         582          2291.91
# 4                    3         388           927.72
#
#    previous_month_end_balance  ...  previous_month_credit  \
# 0                     1458.71  ...                   0.20
# 1                     8704.66  ...                   0.56
# 2                     5815.29  ...                   0.61
# 3                     2291.91  ...                   0.47
# 4                     1401.72  ...                 714.61
#
#    current_month_debit  previous_month_debit  current_month_balance  \
# 0                 0.20                  0.20                1458.71
# 1              5486.27                100.56                6496.78
# 2              6046.73                259.23                5006.28
# 3                 0.47               2143.33                2291.91
# 4               588.62               1538.06                1157.15
#
#    previous_month_balance  churn  doy_ls_tran  woy_ls_tran moy_ls_tran  \
# 0                 1458.71    0.0        141.0           21         5.0
# 1                 8787.61    0.0        305.0           44        11.0
# 2                 5070.14    0.0          NaN         <NA>         NaN
# 3                 1669.79    1.0        218.0           32         8.0
# 4                 1677.16    1.0        307.0           44        11.0
#
#    dow_ls_tran
# 0          1.0
# 1          4.0
# 2          NaN
# 3          1.0
# 4          6.0
#
# [5 rows x 23 columns]

# %% [markdown]
# # Final missing vlaue treatment

# %%
df.dropna(axis=1, inplace=True)  # drop those col which have missing values

# %%
df.isna().sum()
# Out:
# vintage                           0
# age                               0
# gender                            0
# dependents                        0
# occupation                        0
# city                              0
# customer_nw_category              0
# branch_code                       0
# current_balance                   0
# previous_month_end_balance        0
# average_monthly_balance_prevQ     0
# average_monthly_balance_prevQ2    0
# current_month_credit              0
# previous_month_credit             0
# current_month_debit               0
# previous_month_debit              0
# current_month_balance             0
# previous_month_balance            0
# churn                             0
# dtype: int64

# %%
df.to_pickle("churn_prediction_v3.pkl")

# %%
import pandas as pd
df = pd.read_pickle("churn_prediction_v3.pkl")
df.head()
# Out:
#    vintage  age gender  dependents     occupation    city  \
# 0     2401   66   Male           0  self_employed    2004
# 1     2648   35   Male           0  self_employed  100000
# 2     2494   31   Male           0       salaried     146
# 3     2629   90   Male           1  self_employed    1020
# 4     1879   42   Male           2  self_employed    1494
#
#   customer_nw_category branch_code  current_balance  \
# 0                    2         755          1458.71
# 1                    2        3214          5390.37
# 2                    2          41          3913.16
# 3                    2         582          2291.91
# 4                    3         388           927.72
#
#    previous_month_end_balance  average_monthly_balance_prevQ  \
# 0                     1458.71                        1458.71
# 1                     8704.66                        7799.26
# 2                     5815.29                        4910.17
# 3                     2291.91                        2084.54
# 4                     1401.72                        1643.31
#
#    average_monthly_balance_prevQ2  current_month_credit  \
# 0                         1449.07                  0.20
# 1                        12419.41                  0.56
# 2                         2815.94                  0.61
# 3                         1006.54                  0.47
# 4                         1871.12                  0.33
#
#    previous_month_credit  current_month_debit  previous_month_debit  \
# 0                   0.20                 0.20                  0.20
# 1                   0.56              5486.27                100.56
# 2                   0.61              6046.73                259.23
# 3                   0.47                 0.47               2143.33
# 4                 714.61               588.62               1538.06
#
#    current_month_balance  previous_month_balance churn
# 0                1458.71                 1458.71   0.0
# 1                6496.78                 8787.61   0.0
# 2                5006.28                 5070.14   0.0
# 3                2291.91                 1669.79   1.0
# 4                1157.15                 1677.16   1.0
