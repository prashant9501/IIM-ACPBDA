# %%
pwd
# Out:
# 'C:\\Users\\Prashant\\Downloads\\IIM Indore\\Data Analytics'

# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv("churn_prediction.csv")
df.head()  # 1st 5 rows
# Out:
#    customer_id  vintage  age gender  dependents     occupation    city  \
# 0            1     2401   66   Male         0.0  self_employed   187.0
# 1            2     2648   35   Male         0.0  self_employed     NaN
# 2            4     2494   31   Male         0.0       salaried   146.0
# 3            5     2629   90    NaN         NaN  self_employed  1020.0
# 4            6     1879   42   Male         2.0  self_employed  1494.0
#
#    customer_nw_category  branch_code  current_balance  ...  \
# 0                     2          755          1458.71  ...
# 1                     2         3214          5390.37  ...
# 2                     2           41          3913.16  ...
# 3                     2          582          2291.91  ...
# 4                     3          388           927.72  ...
#
#    average_monthly_balance_prevQ  average_monthly_balance_prevQ2  \
# 0                        1458.71                         1449.07
# ...

# %%
path = r"C:\Users\Prashant\Downloads\IIM Indore - May 2024"
df = pd.read_csv(path + "\churn_prediction.csv")
df.head(10)  # 1st 10 rows
# Out:
#    customer_id  vintage  age  gender  dependents     occupation    city  \
# 0            1     2401   66    Male         0.0  self_employed   187.0
# 1            2     2648   35    Male         0.0  self_employed     NaN
# 2            4     2494   31    Male         0.0       salaried   146.0
# 3            5     2629   90     NaN         NaN  self_employed  1020.0
# 4            6     1879   42    Male         2.0  self_employed  1494.0
# 5            7     2223   42  Female         0.0  self_employed  1096.0
# 6            8     2348   72    Male         0.0        retired  1020.0
# 7            9     2309   46    Male         0.0  self_employed   623.0
# 8           10     2353   31    Male         0.0       salaried  1096.0
# 9           11     2595   40    Male         3.0  self_employed  1020.0
#
#    customer_nw_category  branch_code  current_balance  ...  \
# 0                     2          755          1458.71  ...
# ...

# %%
df.tail(20)
# Out:
#        customer_id  vintage  age  gender  dependents     occupation    city  \
# 15910        16976     2726   58  Female         NaN  self_employed    61.0
# 15911        16977     2203   64    Male         1.0  self_employed    11.0
# 15912        16978     2696   49    Male         0.0       salaried   409.0
# 15913        16979     2521   41    Male         0.0  self_employed  1385.0
# 15914        16980     2674   35  Female         0.0  self_employed   146.0
# 15915        16981     2265   54  Female         NaN       salaried   649.0
# 15916        16982     2130   36  Female         1.0       salaried  1096.0
# 15917        16983     1889   53  Female         0.0  self_employed  1258.0
# 15918        16984     2094   48  Female         0.0  self_employed  1439.0
# 15919        16985     2665   33    Male         0.0  self_employed   235.0
# 15920        16988     2536   54    Male         1.0  self_employed   318.0
# ...

# %%
df.sample(10)
# Out:
#        customer_id  vintage  age  gender  dependents     occupation    city  \
# 3144          3351     2492   57  Female         0.0  self_employed  1096.0
# 7533          8020     2711   42    Male         0.0  self_employed  1096.0
# 6530          6959     2242   81  Female         0.0        retired   822.0
# 3151          3359     2738   74    Male         0.0  self_employed  1096.0
# 11276        12048     2249   29    Male         0.0        student  1181.0
# 12881        13754     2260   59    Male         0.0  self_employed   759.0
# 15362        16391     2431   55    Male         0.0       salaried  1135.0
# 2336          2500     2457   45    Male         0.0  self_employed  1636.0
# 4345          4629     2645   44  Female         2.0  self_employed  1597.0
# 11941        12747     2570   32    Male         0.0  self_employed     NaN
#
#        customer_nw_category  branch_code  current_balance  ...  \
# 3144                      2          440           101.53  ...
# ...

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.columns
# Out:
# Index(['customer_id', 'vintage', 'age', 'gender', 'dependents', 'occupation',
#        'city', 'customer_nw_category', 'branch_code', 'current_balance',
#        'previous_month_end_balance', 'average_monthly_balance_prevQ',
#        'average_monthly_balance_prevQ2', 'current_month_credit',
#        'previous_month_credit', 'current_month_debit', 'previous_month_debit',
#        'current_month_balance', 'previous_month_balance', 'last_transaction',
#        'churn'],
#       dtype='object')

# %%
df["age"]
# Out:
# 0        66
# 1        35
# 2        31
# 3        90
# 4        42
#          ..
# 15925    64
# 15926    44
# 15927    34
# 15928    56
# 15929    70
# Name: age, Length: 15930, dtype: int64

# %%
type(df["age"])
# Out:
# pandas.core.series.Series

# %%
df[["age"]]   # same col has been retieved as a DF object
# Out:
#        age
# 0       66
# 1       35
# 2       31
# 3       90
# 4       42
# ...    ...
# 15925   64
# 15926   44
# 15927   34
# 15928   56
# 15929   70
#
# [15930 rows x 1 columns]

# %%
df[["gender", "age"]]
# Out:
#        gender  age
# 0        Male   66
# 1        Male   35
# 2        Male   31
# 3         NaN   90
# 4        Male   42
# ...       ...  ...
# 15925  Female   64
# 15926    Male   44
# 15927  Female   34
# 15928  Female   56
# 15929    Male   70
#
# [15930 rows x 2 columns]

# %%
type(df[["gender", "age"]])
# Out:
# pandas.core.frame.DataFrame

# %%
df.loc[15362]   # row label was used to retieve a single row as pandas SEries
# Out:
# customer_id                            16391
# vintage                                 2431
# age                                       55
# gender                                  Male
# dependents                               0.0
# occupation                          salaried
# city                                  1135.0
# customer_nw_category                       3
# branch_code                               57
# current_balance                      6251.09
# previous_month_end_balance           6236.81
# average_monthly_balance_prevQ        6576.96
# average_monthly_balance_prevQ2       5998.48
# current_month_credit                    0.41
# previous_month_credit                   0.41
# current_month_debit                     0.41
# previous_month_debit                   714.7
# current_month_balance                 6244.2
# previous_month_balance               6678.72
# last_transaction                  2019-10-19
# churn                                    0.0
# ...

# %%
df.loc[[15362, 7533]]   # o/p is DF
# Out:
#        customer_id  vintage  age gender  dependents     occupation    city  \
# 15362        16391     2431   55   Male         0.0       salaried  1135.0
# 7533          8020     2711   42   Male         0.0  self_employed  1096.0
#
#        customer_nw_category  branch_code  current_balance  ...  \
# 15362                     3           57          6251.09  ...
# 7533                      3           26          1091.43  ...
#
#        average_monthly_balance_prevQ  average_monthly_balance_prevQ2  \
# 15362                        6576.96                         5998.48
# 7533                         1674.32                          976.77
#
#        current_month_credit  previous_month_credit  current_month_debit  \
# 15362                  0.41                   0.41                 0.41
# 7533                 913.53                 495.96              1285.96
#
#        previous_month_debit  current_month_balance  previous_month_balance  \
# ...

# %%
df.iloc[:5, :5]
# Out:
#    customer_id  vintage  age gender  dependents
# 0            1     2401   66   Male         0.0
# 1            2     2648   35   Male         0.0
# 2            4     2494   31   Male         0.0
# 3            5     2629   90    NaN         NaN
# 4            6     1879   42   Male         2.0

# %%
df.iloc[3, 2]   # retrieving the vlaue present in the 5th row, 4th col
# Out:
# 90

# %%
df["age"].mean()
# Out:
# 48.17457627118644

# %%
df["age"].median()
# Out:
# 46.0

# %%
df["age"].mode()
# Out:
# 0    90
# Name: age, dtype: int64

# %%
df["age"].std()
# Out:
# 17.865815483337574

# %%
import numpy as np
np.mean(df["age"])
# Out:
# 48.17457627118644

# %%
np.std(df["age"], ddof=1)
# Out:
# 17.865815483337574

# %%
sample_Ages = df["age"].sample(100)
sample_Ages.min(), sample_Ages.max()
# Out:
# (4, 90)

# %%
df["age"].min(), df["age"].max()
# Out:
# (1, 90)

# %%
df["gender"].mode()
# Out:
# 0    Male
# Name: gender, dtype: object

# %%
df["gender"].value_counts()
# Out:
# gender
# Male      9308
# Female    6334
# Name: count, dtype: int64

# %%
df["gender"].value_counts(normalize=True)
# Out:
# gender
# Male      0.595065
# Female    0.404935
# Name: proportion, dtype: float64

# %%
# how many unique vlaues are present in occupation col ?
df["occupation"].value_counts()
# Out:
# occupation
# self_employed    9814
# salaried         3745
# student          1156
# retired          1145
# company            23
# Name: count, dtype: int64

# %%
df["occupation"].value_counts(normalize=True)
# Out:
# occupation
# self_employed    0.617893
# salaried         0.235787
# student          0.072782
# retired          0.072090
# company          0.001448
# Name: proportion, dtype: float64

# %%
df["occupation"].value_counts(normalize=True, dropna=False)  # include the missing values as well
# Out:
# occupation
# self_employed    0.616070
# salaried         0.235091
# student          0.072567
# retired          0.071877
# NaN              0.002950
# company          0.001444
# Name: proportion, dtype: float64

# %%
df["occupation"].nunique()
# Out:
# 5

# %%
df["occupation"].unique()
# Out:
# array(['self_employed', 'salaried', 'retired', 'student', nan, 'company'],
#       dtype=object)

# %%
df.shape  # total number of rows and col in dataset
# Out:
# (15930, 21)

# %%
df.describe().round(2).T
# Out:
#                                   count     mean       std       min      25%  \
# customer_id                     15930.0  8498.09   4910.08      1.00  4245.25
# vintage                         15930.0  2392.44    272.49    438.00  2260.00
# age                             15930.0    48.17     17.87      1.00    35.00
# dependents                      14582.0     0.36      1.09      0.00     0.00
# city                            15470.0   795.16    430.40      0.00   409.00
# customer_nw_category            15930.0     2.22      0.66      1.00     2.00
# branch_code                     15930.0   927.80    937.40      1.00   176.00
# current_balance                 15930.0  7271.42  50511.91  -5503.96  1776.39
# previous_month_end_balance      15930.0  7386.99  49442.42  -2998.64  1908.64
# average_monthly_balance_prevQ   15930.0  7433.50  48935.40   1428.69  2168.16
# average_monthly_balance_prevQ2  15930.0  7183.79  55285.74 -16506.10  1822.05
# ...
